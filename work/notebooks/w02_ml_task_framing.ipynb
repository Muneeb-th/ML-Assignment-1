# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Muneeb-th/ML-Assignment-1/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %% [markdown]
# This is a ranking / scoring problem. Given a set of content pages, I want
# to produce a score that ranks which pages should be reviewed first for
# refresh — not a binary classification of "good" vs "bad" page, but an
# ordered priority list.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %% [markdown]
# The proxy target is is_declining_label = trend_direction == "down", the
# same starter label used in Week 1. This is a proxy because it's a bucket
# computed from the current window, not a true future outcome — a stronger
# version would be "declines over the next 30 days" using a forward-looking
# window.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %% [markdown]
# Precision@50 — of the top 50 pages the system flags for review, how many
# are actually declining? This matches the real decision: a content editor
# can only act on a limited number of pages, so precision at the top of the
# list matters more than overall accuracy.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %% [markdown]
# Each row represents one content page. The key identifiers are content_id
# and client_id, and impressions_90d / trend_direction are examples of the
# signals used to score it.

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/Muneeb-th/ML-Assignment-1/main/data/raw/content_refresh_anonymized.csv")
print("One row =", "one content page, identified by content_id")
df[["content_id", "client_id", "impressions_90d", "trend_direction"]].head(5)
# Out:
# One row = one content page, identified by content_id
#              content_id          client_id  impressions_90d trend_direction
# 0  content_304f48230142  client_f369cb89fc             3803            down
# 1  content_a1fb4e703a9e  client_4e07408562            15320            down
# 2  content_9aa793d4d895  client_7f2253d7e2            12581            down
# 3  content_331d6c4de07b  client_19581e27de            11751          stable
# 4  content_d99b7a2d90ca  client_3fdba35f04            19140            down

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %% [markdown]
# A hand-written rule like "stale AND visible" can only combine a couple of
# conditions with fixed thresholds. But whether a page is truly worth
# reviewing depends on many signals interacting — position, CTR, freshness,
# word count, traffic trend — in ways that shift case by case. In Week 1, a
# decision tree captured more true declining pages in its top 50 than the
# hand rule did, because it could learn those combinations instead of
# relying on one fixed threshold.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [x] Every section above is filled — markdown thinking AND the code that backs it
# - [x] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [x] No client names, URLs, or private queries anywhere
# - [x] My claims use careful words: observed, measured, directional, decision-support
# - [x] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.

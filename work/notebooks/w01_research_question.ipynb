# %% [markdown]
# <a href="https://colab.research.google.com/github/Muneeb-th/ML-Assignment-1/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Muneeb-th/ML-Assignment-1/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# I'm picking Lane 2: Refresh / Content Opportunity Scoring. In Week 1's
# notebooks I already compared a hand-written rule against a learned model
# for scoring which pages need review, and the model matched or beat the
# rule on Precision@50. That's direct evidence this lane has real signal
# worth pursuing.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# Decision: A content editor with limited time needs to prioritize which
# pages to review first. Action: the editor opens the top-ranked pages and
# decides whether to refresh, expand, or leave them. Cost of a wrong call:
# a truly declining page ranked low gets missed and keeps losing traffic;
# a healthy page ranked high wastes the editor's time.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %% [markdown]
# Over half the pages (54.2%) in the starter data show a declining trend,
# and 17 pages are both stale (not updated in 6+ months) and still getting
# meaningful traffic — these are exactly the kind of pages a refresh
# priority system should be catching. That's a strong signal this lane is
# worth building out.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/Muneeb-th/ML-Assignment-1/main/data/raw/content_refresh_anonymized.csv")

declining_rate = (df["trend_direction"] == "down").mean()
stale_visible = ((df["days_since_last_update"] >= 180) & (df["impressions_90d"] >= 500)).sum()

print(f"Declining rate in starter data: {declining_rate:.1%}")
print(f"Pages that are stale AND still visible: {stale_visible}")
print(f"Total pages in dataset: {len(df)}")
# Out:
# Declining rate in starter data: 54.2%
# Pages that are stale AND still visible: 17
# Total pages in dataset: 30000

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# This ranks candidates for review — it does NOT prove that refreshing a
# page will cause it to recover. That would require an actual experiment.
# I'm also not claiming to know Google's ranking algorithm — just working
# with observable signals like traffic and position.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [x] Every section above is filled — markdown thinking AND the code that backs it
# - [x] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [x] No client names, URLs, or private queries anywhere
# - [x] My claims use careful words: observed, measured, directional, decision-support
# - [x] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
